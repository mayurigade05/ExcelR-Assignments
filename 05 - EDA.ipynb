# %% [markdown]
# # Name : Mayuri Mahesh Gade
# ## Assignement No 05
#
# ### EXPLORATORY DATA ANALYSIS ON A DATASET

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the dataset

# %%
df = pd.read_csv("Cardiotocographic.csv")

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.tail()
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %% [markdown]
# # Handling missing values

# %%
#  Impute missing values with the median of each column
df.fillna(df.median(), inplace=True)

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
sns.boxplot(df['ALTV'])
# Out:
# <Axes: ylabel='ALTV'>

# %%
sns.boxplot(df['LB'])
# Out:
# <Axes: ylabel='LB'>

# %% [markdown]
# # Outlier detection and treatment

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
df = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
sns.boxplot(df['LB'])
# Out:
# <Axes: ylabel='LB'>

# %%
sns.boxplot(df['ALTV'])
# Out:
# <Axes: ylabel='ALTV'>

# %% [markdown]
# ## 2. Statistical Summary

# %%
# Statistical summary for each variable
summary = df.describe()

# %%
# Additional summaries for categorical variables (if any)
print(df.describe(include='all'))

# Display the statistical summary
print(summary)
# Out:
#                LB          AC          FM          UC          DL     DS  \
# count  896.000000  896.000000  896.000000  896.000000  896.000000  896.0
# mean   131.859413    0.004036    0.000606    0.004961    0.001547    0.0
# std      9.393070    0.003710    0.001346    0.002707    0.002214    0.0
# min    106.000000   -0.000122   -0.002467   -0.000101   -0.000124    0.0
# 25%    125.000000    0.000006    0.000000    0.003143    0.000000    0.0
# 50%    133.000000    0.003311    0.000000    0.005039    0.000000    0.0
# 75%    138.000000    0.006672    0.000323    0.006927    0.003083    0.0
# max    160.000000    0.013861    0.006272    0.012072    0.008197    0.0
#
#           DP        ASTV        MSTV        ALTV        MLTV       Width  \
# count  896.0  896.000000  896.000000  896.000000  896.000000  896.000000
# mean     0.0   42.465669    1.273759    3.153095    8.596245   67.784187
# std      0.0   15.055465    0.541923    6.032308    4.457159   32.370319
# ...

# %% [markdown]
# # Highlight interesting findings

# %%
#  Checking for skewness
skewness = df.skew()
print(f"Skewness of each variable: \n{skewness}")
# Out:
# Skewness of each variable:
# LB         -0.168397
# AC          0.665139
# FM          2.185018
# UC         -0.074195
# DL          1.259387
# DS          0.000000
# DP          0.000000
# ASTV        0.152756
# MSTV        0.738774
# ALTV        2.135349
# MLTV        0.207506
# Width       0.595626
# Tendency   -0.233553
# NSP         0.000000
# dtype: float64

# %% [markdown]
# # 3. Data Visualization

# %%
# Histogram for each numerical variable


df.hist(bins=15 , figsize=(15 ,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Boxplot to visualize outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.show()

# %%
# Bar chart for categorical variables (if applicable)
# Example: sns.countplot(x='CategoryColumn', data=df)

# %%
sns.pairplot(df)

# %%
# Violin plot to visualize the distribution of a variable
sns.violinplot(x="LB", y="ASTV", data=df)
plt.show()

# %% [markdown]
# # 4. Pattern Recognition and Insights

# %%
# Correlation matrix
corr_matrix=df.corr()
corr_matrix
# Out:
#                 LB        AC        FM        UC        DL  DS  DP      ASTV  \
# LB        1.000000  0.078465  0.007362 -0.023568  0.020806 NaN NaN  0.262721
# AC        0.078465  1.000000  0.080153  0.057284 -0.101866 NaN NaN  0.024343
# FM        0.007362  0.080153  1.000000 -0.204990  0.058476 NaN NaN  0.362630
# UC       -0.023568  0.057284 -0.204990  1.000000  0.177702 NaN NaN -0.004523
# DL        0.020806 -0.101866  0.058476  0.177702  1.000000 NaN NaN  0.001806
# DS             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# DP             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# ASTV      0.262721  0.024343  0.362630 -0.004523  0.001806 NaN NaN  1.000000
# MSTV     -0.254885  0.152222  0.113420  0.110100  0.509405 NaN NaN -0.347374
# ALTV      0.123808 -0.323303 -0.087180 -0.076435 -0.107464 NaN NaN  0.150569
# MLTV     -0.118814 -0.397042 -0.110709 -0.104061 -0.214110 NaN NaN -0.330139
# ...

# %%
# Identify and discuss strong correlations
strong_corr = corr_matrix[(corr_matrix > 0.7) | (corr_matrix < -0.7)]
print("Strong correlations: \n", strong_corr)
# Out:
# Strong correlations:
#             LB   AC   FM   UC   DL  DS  DP  ASTV  MSTV  ALTV  MLTV  Width  \
# LB        1.0  NaN  NaN  NaN  NaN NaN NaN   NaN   NaN   NaN   NaN    NaN
# AC        NaN  1.0  NaN  NaN  NaN NaN NaN   NaN   NaN   NaN   NaN    NaN
# FM        NaN  NaN  1.0  NaN  NaN NaN NaN   NaN   NaN   NaN   NaN    NaN
# UC        NaN  NaN  NaN  1.0  NaN NaN NaN   NaN   NaN   NaN   NaN    NaN
# DL        NaN  NaN  NaN  NaN  1.0 NaN NaN   NaN   NaN   NaN   NaN    NaN
# DS        NaN  NaN  NaN  NaN  NaN NaN NaN   NaN   NaN   NaN   NaN    NaN
# DP        NaN  NaN  NaN  NaN  NaN NaN NaN   NaN   NaN   NaN   NaN    NaN
# ASTV      NaN  NaN  NaN  NaN  NaN NaN NaN   1.0   NaN   NaN   NaN    NaN
# MSTV      NaN  NaN  NaN  NaN  NaN NaN NaN   NaN   1.0   NaN   NaN    NaN
# ALTV      NaN  NaN  NaN  NaN  NaN NaN NaN   NaN   NaN   1.0   NaN    NaN
# MLTV      NaN  NaN  NaN  NaN  NaN NaN NaN   NaN   NaN   NaN   1.0    NaN
# ...

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - **Central Tendencies**: The median and mean values provided insights into the average behavior of the variables.
# - **Variability**: The standard deviation and interquartile range showed the spread of the data.
# - **Correlations**: Strong correlations were observed between variables such as LB and FM, suggesting a possible relationship.
# - **Patterns**: The data visualizations, such as the boxplots and heatmaps, revealed trends and outliers that could be significant for decision-making.
# - **Recommendations**: Further analysis could focus on exploring the relationships between highly correlated variables or temporal patterns (if time data is present).
